# %%
import os
import io
import sys
cwd = os.getcwd()
sys.path.insert(0, cwd)
from module.importData import importData
from module.toWordList import toWordList
from module.steamingWiki import steamingWiki
from module.makeModelGensim import makeModelGensim
from module.toVectore import toVectore
from module.modelLSTM import modelLSTM
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, cohen_kappa_score
import pandas as pd
import numpy as np
import gensim
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
np.set_printoptions(threshold=sys.maxsize)
pd.get_option("display.max_rows", 1000)
pd.set_option('display.max_columns', 1000)

# %%
wikiSource			= 'idwiki'
answerData			= 'DataAnswerExam_SMP.csv'
questionData		= 'qes.csv'
dirData				= cwd+'/data/'
corpusInput			= wikiSource+'.bz2'
wikiOutput			= wikiSource+'.txt'
fileExtension		= 'bin'
trainingAlgoritm	= 0
numDimension		= 200
modelOutput			= wikiSource+'_word2vec_'+str(numDimension)+'_'+str(trainingAlgoritm)+'.'+fileExtension

# %%
dAnswer, dQuestion = importData(answer= dirData+answerData, question= dirData+questionData).openData()

if not(os.path.exists(dirData+modelOutput)):
	if not(os.path.exists(dirData+wikiOutput)):
		steamingWiki(corpusInput=corpusInput, wikiOutput=wikiOutput).execute()
	makeModelGensim(wikiOutput=wikiOutput, modelOutput=modelOutput, numDimension=numDimension, trainingAlgoritm=trainingAlgoritm).execute()

if fileExtension != 'bin':
	model = gensim.models.word2vec.Word2Vec.load(dirData+modelOutput)
else:
	model = gensim.models.KeyedVectors.load_word2vec_format(dirData+modelOutput, unicode_errors='ignore')

# %%
crossVal = KFold(n_splits=2, random_state=True, shuffle=True)

count = 1

# %%
dAnswer.head()
# Out:
#      Essay_id                                             Answer  Score  \
# 0           1  Alumni;  ; Kelebihan; Permisalan; Tutorial; Im...      3
# 120         1  lulusan : alumnus; rencana : agenda; keuntunga...      5
# 365         1  alumni; argument; hasil; example; teknik; imaj...      4
# 650         1  alumnus; agenda; laba; sampel; teknik; imajina...      5
# 125         1  lulusan : alumnus; rencana : agenda; keuntunga...      5
#
#                                             TrueAnswer
# 0    lulusan : alumnus; rencana : agenda; keuntunga...
# 120  lulusan : alumnus; rencana : agenda; keuntunga...
# 365  lulusan : alumnus; rencana : agenda; keuntunga...
# 650  lulusan : alumnus; rencana : agenda; keuntunga...
# 125  lulusan : alumnus; rencana : agenda; keuntunga...

# %%
xtrain = dAnswer.loc[:,['Answer','TrueAnswer']]

# %%
xtrain.head()
# Out:
#                                                 Answer  \
# 0    Alumni;  ; Kelebihan; Permisalan; Tutorial; Im...
# 120  lulusan : alumnus; rencana : agenda; keuntunga...
# 365  alumni; argument; hasil; example; teknik; imaj...
# 650  alumnus; agenda; laba; sampel; teknik; imajina...
# 125  lulusan : alumnus; rencana : agenda; keuntunga...
#
#                                             TrueAnswer
# 0    lulusan : alumnus; rencana : agenda; keuntunga...
# 120  lulusan : alumnus; rencana : agenda; keuntunga...
# 365  lulusan : alumnus; rencana : agenda; keuntunga...
# 650  lulusan : alumnus; rencana : agenda; keuntunga...
# 125  lulusan : alumnus; rencana : agenda; keuntunga...

# %%
for dx, dy in crossVal.split(dAnswer):

	trainSAnswer = []
	trainTAnswer = []
	testSAnswer = []
	testTAnswer = []
	
	print("\n--------Fold {}--------\n".format(count))
	train, test= dAnswer.iloc[dx], dAnswer.iloc[dy]
	
	
	xtrain = train.loc[:,['Answer', 'TrueAnswer']]
	xtest = test.loc[:,['Answer', 'TrueAnswer']]
	ytrain = train.loc[:,['Score']].values
	ytest = test.loc[:,['Score']].values
	
	# bagian ini biar universal aja.
	
	[trainSAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= True)) for a1 in xtrain.loc[:,['Answer']].values]
	[trainTAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= True)) for a1 in xtrain.loc[:,['TrueAnswer']].values]
	[testSAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= True)) for a1 in xtest.loc[:,['Answer']].values]
	[testTAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= True)) for a1 in xtest.loc[:,['TrueAnswer']].values]
	
	vtrainSAnswer, vtrainTAnswer = toVectore(essays = trainSAnswer, trueAnswer=trainTAnswer, model = model, numFeature= numDimension, average=False, distance=True).changeToVector()
	vtestSAnswer, vtestTAnswer = toVectore(essays = testSAnswer, trueAnswer=testTAnswer, model = model, numFeature= numDimension, average=False, distance=True).changeToVector()
	modelNetwork = modelLSTM().biSiamenseModel(inputD=(vtrainSAnswer.shape[1], vtrainSAnswer.shape[2]))
	modelNetwork.fit([vtrainSAnswer, vtrainTAnswer], ytrain, batch_size=100, epochs=30)
	pred = modelNetwork.predict([vtestSAnswer, vtestTAnswer])
# Out:
# --------Fold 1--------
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100, 200)     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 100, 200)     0
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 100, 400)     641600      input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 100, 400)     641600      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 64)           119040      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 64)           119040      bidirectional_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           4160        lstm_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           4160        lstm_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128)          0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            129         concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,529,729
# Trainable params: 1,529,729
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 390/390 [==============================] - 47s 120ms/step - loss: 13.7953 - mean_absolute_error: 3.4832
# Epoch 2/30
# 390/390 [==============================] - 18s 47ms/step - loss: 3.7584 - mean_absolute_error: 1.6606
# Epoch 3/30
# 390/390 [==============================] - 19s 48ms/step - loss: 2.6188 - mean_absolute_error: 1.2281
# Epoch 4/30
# 390/390 [==============================] - 20s 51ms/step - loss: 2.3632 - mean_absolute_error: 1.2076
# Epoch 5/30
# 390/390 [==============================] - 19s 49ms/step - loss: 1.7817 - mean_absolute_error: 1.1520
# Epoch 6/30
# 390/390 [==============================] - 21s 53ms/step - loss: 1.8381 - mean_absolute_error: 1.1710
# Epoch 7/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.5103 - mean_absolute_error: 1.0322
# Epoch 8/30
# 390/390 [==============================] - 26s 67ms/step - loss: 1.5454 - mean_absolute_error: 0.9981
# Epoch 9/30
# 390/390 [==============================] - 18s 47ms/step - loss: 1.5860 - mean_absolute_error: 1.0235
# Epoch 10/30
# 390/390 [==============================] - 18s 47ms/step - loss: 1.4099 - mean_absolute_error: 0.9843
# Epoch 11/30
# 390/390 [==============================] - 18s 47ms/step - loss: 1.3297 - mean_absolute_error: 0.9440
# Epoch 12/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.2622 - mean_absolute_error: 0.9123
# Epoch 13/30
# 390/390 [==============================] - 19s 47ms/step - loss: 1.1932 - mean_absolute_error: 0.8850
# Epoch 14/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.0757 - mean_absolute_error: 0.8313
# Epoch 15/30
# 390/390 [==============================] - 18s 47ms/step - loss: 1.0385 - mean_absolute_error: 0.8267
# Epoch 16/30
# 390/390 [==============================] - 18s 47ms/step - loss: 1.0639 - mean_absolute_error: 0.8066
# Epoch 17/30
# 390/390 [==============================] - 19s 48ms/step - loss: 0.9406 - mean_absolute_error: 0.7709
# Epoch 18/30
# 390/390 [==============================] - 18s 47ms/step - loss: 0.8299 - mean_absolute_error: 0.7232
# Epoch 19/30
# 390/390 [==============================] - 18s 47ms/step - loss: 0.8578 - mean_absolute_error: 0.7179
# Epoch 20/30
# 390/390 [==============================] - 18s 46ms/step - loss: 0.7709 - mean_absolute_error: 0.6818
# Epoch 21/30
# 390/390 [==============================] - 18s 47ms/step - loss: 0.8238 - mean_absolute_error: 0.7212
# Epoch 22/30
# 390/390 [==============================] - 18s 47ms/step - loss: 0.7677 - mean_absolute_error: 0.6915
# Epoch 23/30
# 390/390 [==============================] - 18s 47ms/step - loss: 0.7038 - mean_absolute_error: 0.6611
# Epoch 24/30
# 390/390 [==============================] - 19s 48ms/step - loss: 0.8142 - mean_absolute_error: 0.6927
# Epoch 25/30
# 390/390 [==============================] - 19s 48ms/step - loss: 0.7067 - mean_absolute_error: 0.6485
# Epoch 26/30
# 390/390 [==============================] - 19s 50ms/step - loss: 0.6268 - mean_absolute_error: 0.6283
# Epoch 27/30
# 390/390 [==============================] - 20s 52ms/step - loss: 0.6013 - mean_absolute_error: 0.6273
# Epoch 28/30
# 390/390 [==============================] - 21s 55ms/step - loss: 0.5846 - mean_absolute_error: 0.6027
# Epoch 29/30
# 390/390 [==============================] - 20s 51ms/step - loss: 0.6345 - mean_absolute_error: 0.6165
# Epoch 30/30
# 390/390 [==============================] - 19s 49ms/step - loss: 0.5585 - mean_absolute_error: 0.5858
#
# --------Fold 1--------
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 100, 200)     0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 100, 200)     0
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 100, 400)     641600      input_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 100, 400)     641600      input_4[0][0]
# __________________________________________________________________________________________________
# lstm_6 (LSTM)                   (None, 64)           119040      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   (None, 64)           119040      bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           4160        lstm_6[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           4160        lstm_8[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128)          0           dropout_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            129         concatenate_2[0][0]
# ==================================================================================================
# Total params: 1,529,729
# Trainable params: 1,529,729
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/30
# 390/390 [==============================] - 32s 83ms/step - loss: 14.1259 - mean_absolute_error: 3.5249
# Epoch 2/30
# 390/390 [==============================] - 19s 48ms/step - loss: 3.5535 - mean_absolute_error: 1.6229
# Epoch 3/30
# 390/390 [==============================] - 19s 48ms/step - loss: 3.1438 - mean_absolute_error: 1.3455
# Epoch 4/30
# 390/390 [==============================] - 19s 48ms/step - loss: 2.4539 - mean_absolute_error: 1.2155
# Epoch 5/30
# 390/390 [==============================] - 19s 48ms/step - loss: 2.1983 - mean_absolute_error: 1.2921
# Epoch 6/30
# 390/390 [==============================] - 18s 47ms/step - loss: 2.0144 - mean_absolute_error: 1.2316
# Epoch 7/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.6355 - mean_absolute_error: 1.0480
# Epoch 8/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.8223 - mean_absolute_error: 1.0497
# Epoch 9/30
# 390/390 [==============================] - 20s 51ms/step - loss: 1.5154 - mean_absolute_error: 0.9751
# Epoch 10/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.5006 - mean_absolute_error: 1.0304
# Epoch 11/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.3949 - mean_absolute_error: 0.9780
# Epoch 12/30
# 390/390 [==============================] - 19s 47ms/step - loss: 1.2793 - mean_absolute_error: 0.9243
# Epoch 13/30
# 390/390 [==============================] - 19s 48ms/step - loss: 1.3245 - mean_absolute_error: 0.9271
# Epoch 14/30
# 390/390 [==============================] - 20s 52ms/step - loss: 1.2256 - mean_absolute_error: 0.8783
# Epoch 15/30
# 390/390 [==============================] - 19s 50ms/step - loss: 1.1560 - mean_absolute_error: 0.8601
# Epoch 16/30
# 390/390 [==============================] - 20s 52ms/step - loss: 0.9969 - mean_absolute_error: 0.7775
# Epoch 17/30
# 390/390 [==============================] - 19s 49ms/step - loss: 0.9986 - mean_absolute_error: 0.7829
# Epoch 18/30
# 390/390 [==============================] - 19s 49ms/step - loss: 0.9473 - mean_absolute_error: 0.7525
# Epoch 19/30
# 390/390 [==============================] - 21s 54ms/step - loss: 0.9609 - mean_absolute_error: 0.7559
# Epoch 20/30
# 390/390 [==============================] - 21s 53ms/step - loss: 0.7673 - mean_absolute_error: 0.6679
# Epoch 21/30
# 390/390 [==============================] - 19s 50ms/step - loss: 0.8817 - mean_absolute_error: 0.7438
# Epoch 22/30
# 390/390 [==============================] - 19s 49ms/step - loss: 0.8291 - mean_absolute_error: 0.7060
# Epoch 23/30
# 390/390 [==============================] - 19s 48ms/step - loss: 0.7632 - mean_absolute_error: 0.6634
# Epoch 24/30
# 390/390 [==============================] - 18s 47ms/step - loss: 0.7361 - mean_absolute_error: 0.6556
# Epoch 25/30
# 390/390 [==============================] - 19s 49ms/step - loss: 0.7945 - mean_absolute_error: 0.6942
# Epoch 26/30
# 390/390 [==============================] - 20s 51ms/step - loss: 0.7132 - mean_absolute_error: 0.6468
# Epoch 27/30
# 390/390 [==============================] - 20s 51ms/step - loss: 0.7159 - mean_absolute_error: 0.6622
# Epoch 28/30
# 390/390 [==============================] - 19s 50ms/step - loss: 0.6749 - mean_absolute_error: 0.6277
# Epoch 29/30
# 390/390 [==============================] - 20s 50ms/step - loss: 0.6736 - mean_absolute_error: 0.6262
# Epoch 30/30
# 390/390 [==============================] - 19s 48ms/step - loss: 0.7058 - mean_absolute_error: 0.6394

# %%
dfa = pd.DataFrame()

# %%
dfa.insert(0,'actual',ytest.flatten())
dfa.insert(1,'roundpredict',np.around(pred).flatten())
dfa.insert(2,'predict',pred.flatten())

# %%
dfa
# Out:
#      actual  roundpredict   predict
# 0         5           5.0  5.033740
# 1         4           3.0  2.900996
# 2         5           5.0  5.149524
# 3         5           5.0  5.048888
# 4         5           5.0  5.096538
# 5         5           5.0  4.994704
# 6         5           5.0  5.133086
# 7         5           5.0  5.162828
# 8         5           5.0  5.057400
# 9         5           5.0  5.029446
# 10        5           5.0  5.061579
# 11        3           4.0  4.478174
# 12        5           5.0  4.950711
# 13        5           5.0  5.080461
# 14        3           5.0  4.976826
# 15        5           5.0  5.043297
# 16        5           5.0  5.162828
# 17        5           5.0  5.072916
# 18        5           5.0  5.018955
# 19        5           5.0  5.050449
# 20        5           5.0  5.162828
# 21        5           5.0  5.142506
# 22        5           5.0  5.159063
# 23        5           5.0  4.767264
# 24        5           5.0  5.008848
# 25        5           5.0  5.162828
# 26        5           5.0  5.162828
# 27        5           5.0  5.004520
# 28        5           5.0  5.082612
# 29        5           5.0  5.058642
# ..      ...           ...       ...
# 360       5           4.0  3.918106
# 361       5           5.0  4.993066
# 362       5           3.0  3.120159
# 363       4           5.0  4.902997
# 364       3           5.0  4.912392
# 365       3           4.0  4.246290
# 366       4           4.0  4.278971
# 367       5           4.0  4.239525
# 368       5           5.0  4.689455
# 369       4           4.0  3.993698
# 370       5           5.0  5.269809
# 371       5           6.0  5.507656
# 372       5           6.0  5.541989
# 373       5           5.0  5.334135
# 374       5           6.0  5.507656
# 375       5           6.0  5.507656
# 376       5           6.0  5.532556
# 377       5           5.0  5.201718
# 378       5           5.0  5.477523
# 379       5           5.0  5.077940
# 380       5           6.0  5.542554
# 381       5           4.0  4.381052
# 382       5           5.0  5.443629
# 383       5           3.0  3.415975
# 384       5           4.0  4.392621
# 385       5           5.0  4.799441
# 386       5           4.0  3.705568
# 387       5           5.0  5.004694
# 388       4           4.0  4.319669
# 389       5           5.0  4.759518
#
# [390 rows x 3 columns]

# %%
cohen_kappa_score(ytest, np.around(pred), weights='quadratic')
# Out:
# 0.8258392362180474

# %%
mean_squared_error(ytest, np.around(pred))
# Out:
# 0.4461538461538462

# %%
mean_absolute_error(ytest, np.around(pred))
# Out:
# 0.2923076923076923
