# %%
import os
import io
import sys
cwd = os.getcwd()
sys.path.insert(0, cwd)
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, cohen_kappa_score
import pandas as pd
import numpy as np
import gensim

np.set_printoptions(threshold=sys.maxsize)
from keras.models import load_model
np.set_printoptions(threshold=sys.maxsize)
pd.get_option("display.max_rows", 1000)
pd.set_option('display.max_columns', 1000)
# Out:
# Using TensorFlow backend.

# %%
from module.importData import importData
from module.toWordList import toWordList
from module.steamingWiki import steamingWiki
from module.makeModelGensim import makeModelGensim
from module.toVectore import toVectore
from module.modelLSTM import modelLSTM

# %%
wikiSource			= 'idwiki'
answerData			= 'DataAnswerExam_SMP.csv'
# answerData			= 'aes.csv'
# answerData			= 'aesnormal.csv'
#questionData		= 'DataQuestionExam_SMP.csv'
questionData		= 'qes.csv'
dirData				= cwd+'/data/'
corpusInput			= wikiSource+'.bz2'
wikiOutput			= wikiSource+'.txt'
fileExtension		= 'bin'
trainingAlgoritm	= 1
numDimension		= 200
modelOutput			= wikiSource+'_word2vec_'+str(numDimension)+'_'+str(trainingAlgoritm)+'.'+fileExtension

# %%
dAnswer, dQuestion = importData(answer= dirData+answerData, question= dirData+questionData).openData()

if not(os.path.exists(dirData+modelOutput)):
	if not(os.path.exists(dirData+wikiOutput)):
		steamingWiki(corpusInput=corpusInput, wikiOutput=wikiOutput).execute()
	makeModelGensim(wikiOutput=wikiOutput, modelOutput=modelOutput, numDimension=numDimension, trainingAlgoritm=trainingAlgoritm).execute()

if fileExtension != 'bin':
	model = gensim.models.word2vec.Word2Vec.load(dirData+modelOutput)
else:
	model = gensim.models.KeyedVectors.load_word2vec_format(dirData+modelOutput, unicode_errors='ignore')

# %%
msea =[]
maea =[]
kappa = []
file1 = io.open("small.txt", "w")
file2 = io.open("all.txt", "w")
filea = io.open("ma.txt", "w")
fileb = io.open("mb.txt", "w")
filec = io.open("mc.txt", "w")

# %%
for x in (dQuestion.loc[:,'Essay_id'].values):
	if x in dAnswer.loc[:,'Essay_id'].values:
		xdAnswer = dAnswer.loc[dAnswer['Essay_id'] == x]
		xdQuestion = dQuestion.loc[dQuestion['Essay_id'] == x]
		crossVal = KFold(n_splits=2, random_state=None, shuffle=True)
		results = []
		resultaa = []
		resultbb = []
		resultkappaa = []
		resultkappab = []
		resultkappac = []

		count = 1

		for dx, dy in crossVal.split(xdAnswer):
			df1 = pd.DataFrame() 
			df2 = pd.DataFrame() 
			dfa = pd.DataFrame() 
			dfb = pd.DataFrame() 
			dfc = pd.DataFrame() 
			trainStudentAnswer = []
			testStudentAnswer = []
			trueAnswer = []
			question = []
			
			print("\n--------Fold {}--------\n".format(count))
			train, test= xdAnswer.iloc[dx], xdAnswer.iloc[dy]
			
			xtrain = train.loc[:,['Answer']]
			xtest = test.loc[:,['Answer']]
			ytrain = train.loc[:,['Score']].values
			ytest = test.loc[:,['Score']].values
			[print(a1[0]) for a1 in xtrain.values]
			[trainStudentAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= False, question=xdQuestion.loc[:,'Question'].values[0])) for a1 in xtrain.values]
			[testStudentAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= False, question=xdQuestion.loc[:,'Question'].values[0])) for a1 in xtest.values]
			#[trueAnswer.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= False, question=xdQuestion.loc[:,'Question'].values[0])) for a1 in xdQuestion.loc[:,['Answer']].values]
			#[question.append(toWordList().sentenceToWordList(a1[0], changeNumber2Word= False, question=xdQuestion.loc[:,'Question'].values[0])) for a1 in xdQuestion.loc[:,['Question']].values]    
			
			#dataAnswerXTrain, dataTrueAnswerX = toVectore(essays = trainStudentAnswer, trueAnswer=trueAnswer, model = model, numFeature= numDimension, average=False, distance=True).changeToVector()
			#dataAnswerYTest, dataTrueAnswerY = toVectore(essays = testStudentAnswer, trueAnswer=trueAnswer, model = model, numFeature= numDimension, average=False, distance=True).changeToVector()
			
			#modelNetworka = modelLSTM().getModel()
			#modelNetworkb = modelLSTM().getModel(rs=True)
			#modelNetworkb = modelLSTM().biGetModel(inputD=(dataAnswerXTrain.shape[1], dataAnswerXTrain.shape[2]))
			#modelNetworkc = modelLSTM().siamenseModel(inputD=(dataAnswerXTrain.shape[1], dataAnswerXTrain.shape[2]))
			#modelNetworkd = modelLSTM().biSiamenseModel(inputD=(dataAnswerXTrain.shape[1], dataAnswerXTrain.shape[2]))
			#modelNetworka = load_model(dirData+'model/lstm_model_a'+str(x)+'.h5')
			#modelNetworkb = load_model(dirData+'model/lstm_model_b'+str(x)+'.h5')
            
            

			#modelNetworka.fit(dataAnswerXTrain, ytrain, batch_size=10, epochs=10)
			#modelNetworkb.fit(dataAnswerXTrain, ytrain, batch_size=10, epochs=10)
			#modelNetworkb.fit([dataAnswerXTrain, dataTrueAnswerX], ytrain, batch_size=25, epochs=100)
			#modelNetworkd.fit([dataAnswerXTrain, dataTrueAnswerX], ytrain, batch_size=10, epochs=10)
			#ypred = modelNetworka.predict(dataAnswerXTest)
			#ypred = modelNetworkd.predict([dataAnswerYTest, dataTrueAnswerY])
			#ypredb = modelNetworkb.predict(dataAnswerXTest)
			#modelNetworkd.save_weights(dirData+'model/lstm_modelasdw_'+str(x)+'.h5')
			#dfa.insert(0,'actual',ytest.flatten())
			#dfa.insert(1,'predict',np.around(ypred).flatten())
			#dfb.insert(0,'actual',ytest.flatten())
			#dfb.insert(1,'predict',np.around(ypredb).flatten())
			#filea.write("==========="+str(x)+"========= fold "+str(count))
			#filea.write(str(dfa.values))
			#filea.write('\n')
			#fileb.write("==========="+str(x)+"========= fold "+str(count))
			#fileb.write(str(dfb.values))
			#fileb.write('\n')
			#resultkappaa.append(cohen_kappa_score(ytest, np.around(ypred), weights='quadratic'))
			#resultkappab.append(cohen_kappa_score(ytest, np.around(ypredb), weights='quadratic'))
			#resultkappac.append(cohen_kappa_score(ytest, np.around(ypredc), weights='quadratic'))
			#count += 1
		#filea.write("=======================================================")
		#filea.write('\n')
		#filea.write(str(resultkappaa))
		#fileb.write("=======================================================")
		#fileb.write('\n')
		#fileb.write(str(resultkappab))
# Out:
# --------Fold 1--------
#
# orientasi : berisi informasi dasar drama (tokoh, latar, dll); tafsiran : sinopsis drama; evaluasi : penilaian terhadap drama; rangkuman : ringkasan drama
# orientasi : gambaran umum mengenai objek; tafsiran : gambaran atau pendapat penonton mengenai objek; evaluasi : meneliti kekurangan objek; ranguman / ringkasan : rangkuman atau ringkasan secara keseluruhan
# ringkasan; evaluasi; orientasi; rangkuman
# orientasi : pengenalan; tafsiran : pendahuluan; evaluasi : pendapat; kesimpulan : amanat/ kesimpulan
# orientasi - membaca cepat benar; evaluasi - mengevaluasi bacaan; rangkuman : merangkum bacaan; memahami : memahami bacaan
# paragraf pembuka : pembukaan teks; paragraf isi : isi teks; paragraf penutup : penutup teks
# tema; topik; sumber; waktu dan tempat; kejadian
# orientasi; tafsiran; rangkuman; ulasan
# orientasi : gambaran umum tentang objek yang diulas; tafsiran : pandangan pengulas terhadap objek yang diulas; evaluasi : penilaian terhadap objek yang diulas; rangkuman : ringkasan / kesimpulan ulasan
# evaluasi : mengevaluasi yang diulas; ringkasan : ringkasan/ kesimpulan isi ulasan; orientas :
# pencahayaan : dimatikan saat pergantian adegan; kostum : agar penonton dapat membedakan peran; suara : harus keras walaupun tidak memakai mikrofon; latar : harus jelas latarnya agar mudah dipahami; musik : pendukung suasana drama
# teknik outline; teknik olah suara; teknik olah wajah
# orientasi : gambaran umum tentang objek yg diulas; tafsiran : pandangan pengulas dari objek yg diulas; evaluasi: penelitian/ pengamatan/ evaluasi terhadap objek yang diulas; ringkasan : rangkuman dari isi ulasan
# orientasi : menggambarkan tentang objek yang kita lihat; tafsiran : menafsirkan objek yang kita lihat; evalusai : mengevaluasi objek yang dilihat; rangkuman : merangkum dari apa yang kita lihat
# tema : hal yang akan dibahas; alur : jalan cerita; latar : tempat dan waktu dilaksanakan; bahasa : kata yang sesuai; amanat : hal yang bisa diambil
# tata riasan; tata cahaya; tata musik; tata penyutradaraan
# orientasi : terdiri dari nama tokoh, peran tokoh, tema, dan judul; isi : terdiri dari sinopsis, alur, dan latar; evalusai : terdiri kritik dan saran tentang aspek-aspek drama; aspek akting; aspek kostum; aspek tata rias; aspek setting; aspek pencahayaan dan lainnya; rangkuman : terdiri dari amanat yang ingin disampaikan
# kritik : mengomentari negatif; saran : memberikan solusi positif
# 5w + 1h; what (apa); when (kapan); who (siapa); where (dimana); why (mengapa); how (bagaimana)
# orientasi : penjelasan seperti tokoh, judul, setting; tafsiran : alur drama; evaluasi : kritik dan saran; rangkuman : kesimpulan, amanat
# orientasi : gambaran umum tentang objek yang diulas (judul, contoh + peran, latar); tafsiran : pandangan pada objek yang diulas (sinopsis); evaluasi : penilaian tentang objek yang diulas (kritik, saran); rangkuman : ringkasan tentang ulasan tersebut (amanat)
# non formal : tidak harus menggunakan kata bantu; sopan : tidak menggunakan kata kasar; jelas : harus jelas/ mudah dipahami
# teks ulasan membuat sesuatu : membuat relief tekan; teks ulasan melakukan sesuatu : menyetrika, memasak
# orientasi : adalah gambaran ulang terhadap objek; tafsiran : adalah ulasan terhadap objek; evaluasi : adalah penilaian terhadap objek; rangkuman : ringkasan isi ulasan
# judul : judul dalam teks tersebut; anotasi; dialog : percakapan; babak/ adegan
# volume suara : dapat didengar oleh seluruh audiens; vokal : dapat didengar secara jelas; penjelasan : pemberhentian ditengah atau diakhir kalimat; ekspresi : mimik wajah; gerak gerik : mengurangi gerakan yang tidak perlu; bahasa yang komunikatif: penggunaan bahasa indonesia dengan baik dan benar
# pembukaan -> salam; isi -> tujuan; penutup-> salam penutup dan terimakasih
# sutradara : mengatur jalannya pementasan ; alur : jalan cerita; panggung : tempat pementasan drama; amanat : pesan yang terkandung dalam drama
# orientasi : gambaran umum tentang objek yang diulas; tafsiran : gambaran pengulas tentang objek yang diulas; evaluasi : isi usulan & saran-saran pengulas; rangkuman : ringkasan ulasan & amanat
# ada penomorannya; secara urutan; gampang dipahami
# 5w + 1h -> 5w  :  why, who, what, why, where + 1h = how; berupa fakta; judul
# bahasa komunikatif : menggunakan bahasa indonesia yang baik dan benar; tanda baca : harus memperhatikan tanda baca; huruf kapital : harus memperhatikan penggunaan huruf besar
# bersifat benar; bersifat aktual; berasal dari sumber yang terpercaya
# teks usulan : tema, tokoh, latar, alur, amanat, bahasa
# bahasa -> bahasa yang digunakan bagaimana; pokok-pokok informasi -> isi dari teks tersebut
# pendapat; gagasan utama; alur
# bahasa yang baik dan benar; menggunakan bahasa baku
# alur; ringkasan; kritik saran; evaluasi; sinopsis
# penyutradaraan : sutradara adala orang yang mengatur tim dan jalannya drama; aktor/ aktris : peran, yang memerankan tokoh; tata cahaya : cahaya, gelap terang; tata rias : costum, make up; tata musik : backsound drama tersebut; dialog : pembicaraan yang dilakukan antar tokoh
# tek usulan adalah teks yang bertujuan untuk mengulas sebuah cerita
# orientasi : gambaran umum tentang sesuatu yang akan diulas. cth : tokoh, latar; tafsiran : pandangan pengulas terhadap sesuatu yang akan diulas. (sinopsis); evaluasi : penilaian terhadap sesuatu yang diulas bisa berupa kritik, saran; rangkuman : ringkasan/ isi dari yang diulas (amanat)
# what (apa) : apa yang dilakukan?; who (siapa) : siapa yang melakukannya ?; when (kapan) : kapan dilakukannya?; where (dimana) : dimana melakukannya ?; why (mengapa) : mengapa ini dilakukan ? ; how (bagaimana) : bagaimana cara melakukannya ?
# orientasi : penggamar semuanya pada teks, tokoh, tempat, latar, suasana. dll; tafsiran: pandangan pengamat tentang apa yang terjadi; evaluasi : penilaian kurang dan lebihnya; rangkuman : simpulan dari teks
# orientasi : gambaran umum mengenai objek yang diulas; tafsiran : pandangan pengulas terhadap objek yang diulas; evaluasi : penilaian mengenai objek yang diulas; rangkuman : kesimpulan atau ringkasan dari ulasan
# teks ulasan : teks yang mengulas sesuatu; unsur-unsur : rangkuman : menulis hasil ringkasan; orientasi : melihat secara objektif; argumen : melihat secara faktual; reorientasi : melihat secara aktual
# jelas, mudah difahami, bahasa baku; harus ada pokok-pokok intinya
# orientasi : pengenalan tokoh/ aktor/ aktris; argumen : menemukan kesalahan-kesalahan pada teks drama; evaluasi : mengevaluasi kesalahan-kesalahan pada teks drama; amanat : pesan-pesan yang dapat diberikan pada naskah drama
# orientasi : menggambarkan teks yang diulas; tafsiran : seperti sinopsi; evaluasi : penilaian terhadap teks yang diulas
# orientasi : penjelasan dari drama; judul : tema dari drama; bahasa : bahasa harus baku; amanat : pesan yang disampaikan/ pesan moral
# teks prosedur melakukan; yaitu melakukan sesuatu rangkaian kegiatan yang hasil akhirnya adalah akhir kegiatan; teks prosedur membuat; yaitu teks urutan membuat sesuatu yang hasil akhirnya produk
# orientasi : gambaran umum tentang objek yang ingin diulas; tafsiran : pandangan tentang objek yang ingin diulas (ringkasan dan sinopsis); evaluasi : penilaian objek yang ingin diulas; rangkuman : rangkuman atau isi dari hasil ulasan (amanat)
# orientasi : gambaran luas tentang sesuatu yang diulas; tafsiran : pandangan pengulas terhadap sesuatu yang diulas; ringkasan : rangkuman atau kesimpulan dari suatu yang diulas; evaluasi : penilaian terhadap sesuatu yang diulas
# unsur-unsur teks ulasan :; berisi hal-hal yang akan disampaikan; disampaikan secara komunikatif; kesimpulan; pokok-pokok yang disampaikan didalam isi; kritik, saran, dan pendapat; disampaikan secara santun
# orientasi : pengenalan [tokoh, judul]; tafsiran : sinopsis; evaluasi : kritik dan saran; rangkuman : alur secara garis besar
# membaca teks; mengevaluasi; memperbaiki; membenarkan
# orientasi : gambaran umum tentang apa yang akan diulas; tafsiran : gambaran pengulas terhadap objek yang diulas; evaluasi : penilaian terhadap objek yang diulas; rangkuman : ringkasan atau rangkuman tentang apa yang telah diulas
# tata cahaya; mengulas tentang pencahayaan  saat drama; aspek penyutradaraan; mengulas tentang alur cerita; tata setting; mengulas tentang penempatan benda2 yang diperlukan saat drama; tata rias; mengulas makeup para pemeran drama
# orientasi : pengenalan drama. berupa judul, latar, dan tokoh; tafsiran : berisi alur drama; evaluasi : berisi tentang evaluasi drama. bisa berupa kekurangan dan saran; rangkuman : berisi tentang amanat
# kop surat; alamat surat; salam pembuka, paragraf pembuka, paragraf isi, paragraf penutup, salam penutup
# bahasa yang komunikatif: baik & benar, mudah dipahami; kata baku : kata  yang baku; memiliki arti : jangan yang tidak memiliki arti; bersifat konkret : nyata
# unsur2 teks ulasan; terdapat teks yg ingin diulas; membaca teks; mencatat hal2 pokok
# evalusai : penilaian objek ; simpulan : ringkasan; orientasi : pandangan terhadap objek; tafsiran : penjelasan hal-hal yang terdapat diobjek
# gagasan utama; pokok utama
# saran; kritikan; pendapat
# orientasi; -> pandangan awal dari pementasan; tafsiran; -> isi dari pementasan; evaluasi; -> koreksi dari pementasan; ringkasan; -> rangkuman/ ringkasan dari apa yang dipentaskan
# orientasi : gambaran umum objek yang akan diulas; tafsiran : pandangan pengulas terhadap objek yang akan diulas; evaluasi : pendapat pengulas terhadap yang diulas; rangkuman : perbaikan yang disampaikan sang pengulas
# orientasi : pendangan umum terhadap teks ulasan; tafsiran : pandangan pengulas terhadap teks ulasan; evaluasi : penilaian terhadap teks ulasan; rangkuman : ringkasan/ kesimpulan teks ulasan
# orientasi   berisi informasi dasar drama  tokoh  latar  dll   tafsiran   sinopsis drama  evaluasi   penilaian terhadap drama  rangkuman   ringkasan drama
# orientasi   gambaran umum mengenai objek  tafsiran   gambaran atau pendapat penonton mengenai objek  evaluasi   meneliti kekurangan objek  ranguman   ringkasan   rangkuman atau ringkasan secara keseluruhan
# ringkasan  evaluasi  orientasi  rangkuman
# orientasi   pengenalan  tafsiran   pendahuluan  evaluasi   pendapat  kesimpulan   amanat  kesimpulan
# orientasi   membaca cepat benar  evaluasi   mengevaluasi bacaan  rangkuman   merangkum bacaan  memahami   memahami bacaan
# paragraf pembuka   pembukaan teks  paragraf isi   isi teks  paragraf penutup   penutup teks
# tema  topik  sumber  waktu dan tempat  kejadian
# orientasi  tafsiran  rangkuman  ulasan
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   ringkasan   kesimpulan ulasan
# evaluasi   mengevaluasi yang diulas  ringkasan   ringkasan  kesimpulan isi ulasan  orientas
# pencahayaan   dimatikan saat pergantian adegan  kostum   agar penonton dapat membedakan peran  suara   harus keras walaupun tidak memakai mikrofon  latar   harus jelas latarnya agar mudah dipahami  musik   pendukung suasana drama
# teknik outline  teknik olah suara  teknik olah wajah
# orientasi   gambaran umum tentang objek yg diulas  tafsiran   pandangan pengulas dari objek yg diulas  evaluasi  penelitian  pengamatan  evaluasi terhadap objek yang diulas  ringkasan   rangkuman dari isi ulasan
# orientasi   menggambarkan tentang objek yang kita lihat  tafsiran   menafsirkan objek yang kita lihat  evalusai   mengevaluasi objek yang dilihat  rangkuman   merangkum dari apa yang kita lihat
# tema   hal yang akan dibahas  alur   jalan cerita  latar   tempat dan waktu dilaksanakan  bahasa   kata yang sesuai  amanat   hal yang bisa diambil
# tata riasan  tata cahaya  tata musik  tata penyutradaraan
# orientasi   terdiri dari nama tokoh  peran tokoh  tema  dan judul  isi   terdiri dari sinopsis  alur  dan latar  evalusai   terdiri kritik dan saran tentang aspek aspek drama  aspek akting  aspek kostum  aspek tata rias  aspek setting  aspek pencahayaan dan lainnya  rangkuman   terdiri dari amanat yang ingin disampaikan
# kritik   mengomentari negatif  saran   memberikan solusi positif
# 5w   1h  what  apa   when  kapan   who  siapa   where  dimana   why  mengapa   how  bagaimana
# orientasi   penjelasan seperti tokoh  judul  setting  tafsiran   alur drama  evaluasi   kritik dan saran  rangkuman   kesimpulan  amanat
# orientasi   gambaran umum tentang objek yang diulas  judul  contoh   peran  latar   tafsiran   pandangan pada objek yang diulas  sinopsis   evaluasi   penilaian tentang objek yang diulas  kritik  saran   rangkuman   ringkasan tentang ulasan tersebut  amanat
# non formal   tidak harus menggunakan kata bantu  sopan   tidak menggunakan kata kasar  jelas   harus jelas  mudah dipahami
# teks ulasan membuat sesuatu   membuat relief tekan  teks ulasan melakukan sesuatu   menyetrika  memasak
# orientasi   adalah gambaran ulang terhadap objek  tafsiran   adalah ulasan terhadap objek  evaluasi   adalah penilaian terhadap objek  rangkuman   ringkasan isi ulasan
# judul   judul dalam teks tersebut  anotasi  dialog   percakapan  babak  adegan
# volume suara   dapat didengar oleh seluruh audiens  vokal   dapat didengar secara jelas  penjelasan   pemberhentian ditengah atau diakhir kalimat  ekspresi   mimik wajah  gerak gerik   mengurangi gerakan yang tidak perlu  bahasa yang komunikatif  penggunaan bahasa indonesia dengan baik dan benar
# pembukaan    salam  isi    tujuan  penutup   salam penutup dan terimakasih
# sutradara   mengatur jalannya pementasan   alur   jalan cerita  panggung   tempat pementasan drama  amanat   pesan yang terkandung dalam drama
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   gambaran pengulas tentang objek yang diulas  evaluasi   isi usulan   saran saran pengulas  rangkuman   ringkasan ulasan   amanat
# ada penomorannya  secara urutan  gampang dipahami
# 5w   1h    5w     why  who  what  why  where   1h   how  berupa fakta  judul
# bahasa komunikatif   menggunakan bahasa indonesia yang baik dan benar  tanda baca   harus memperhatikan tanda baca  huruf kapital   harus memperhatikan penggunaan huruf besar
# bersifat benar  bersifat aktual  berasal dari sumber yang terpercaya
# teks usulan   tema  tokoh  latar  alur  amanat  bahasa
# bahasa    bahasa yang digunakan bagaimana  pokok pokok informasi    isi dari teks tersebut
# pendapat  gagasan utama  alur
# bahasa yang baik dan benar  menggunakan bahasa baku
# alur  ringkasan  kritik saran  evaluasi  sinopsis
# penyutradaraan   sutradara adala orang yang mengatur tim dan jalannya drama  aktor  aktris   peran  yang memerankan tokoh  tata cahaya   cahaya  gelap terang  tata rias   costum  make up  tata musik   backsound drama tersebut  dialog   pembicaraan yang dilakukan antar tokoh
# tek usulan adalah teks yang bertujuan untuk mengulas sebuah cerita
# orientasi   gambaran umum tentang sesuatu yang akan diulas  cth   tokoh  latar  tafsiran   pandangan pengulas terhadap sesuatu yang akan diulas   sinopsis   evaluasi   penilaian terhadap sesuatu yang diulas bisa berupa kritik  saran  rangkuman   ringkasan  isi dari yang diulas  amanat
# what  apa    apa yang dilakukan   who  siapa    siapa yang melakukannya    when  kapan    kapan dilakukannya   where  dimana    dimana melakukannya    why  mengapa    mengapa ini dilakukan     how  bagaimana    bagaimana cara melakukannya
# orientasi   penggamar semuanya pada teks  tokoh  tempat  latar  suasana  dll  tafsiran  pandangan pengamat tentang apa yang terjadi  evaluasi   penilaian kurang dan lebihnya  rangkuman   simpulan dari teks
# orientasi   gambaran umum mengenai objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian mengenai objek yang diulas  rangkuman   kesimpulan atau ringkasan dari ulasan
# teks ulasan   teks yang mengulas sesuatu  unsur unsur   rangkuman   menulis hasil ringkasan  orientasi   melihat secara objektif  argumen   melihat secara faktual  reorientasi   melihat secara aktual
# jelas  mudah difahami  bahasa baku  harus ada pokok pokok intinya
# orientasi   pengenalan tokoh  aktor  aktris  argumen   menemukan kesalahan kesalahan pada teks drama  evaluasi   mengevaluasi kesalahan kesalahan pada teks drama  amanat   pesan pesan yang dapat diberikan pada naskah drama
# orientasi   menggambarkan teks yang diulas  tafsiran   seperti sinopsi  evaluasi   penilaian terhadap teks yang diulas
# orientasi   penjelasan dari drama  judul   tema dari drama  bahasa   bahasa harus baku  amanat   pesan yang disampaikan  pesan moral
# teks prosedur melakukan  yaitu melakukan sesuatu rangkaian kegiatan yang hasil akhirnya adalah akhir kegiatan  teks prosedur membuat  yaitu teks urutan membuat sesuatu yang hasil akhirnya produk
# orientasi   gambaran umum tentang objek yang ingin diulas  tafsiran   pandangan tentang objek yang ingin diulas  ringkasan dan sinopsis   evaluasi   penilaian objek yang ingin diulas  rangkuman   rangkuman atau isi dari hasil ulasan  amanat
# orientasi   gambaran luas tentang sesuatu yang diulas  tafsiran   pandangan pengulas terhadap sesuatu yang diulas  ringkasan   rangkuman atau kesimpulan dari suatu yang diulas  evaluasi   penilaian terhadap sesuatu yang diulas
# unsur unsur teks ulasan    berisi hal hal yang akan disampaikan  disampaikan secara komunikatif  kesimpulan  pokok pokok yang disampaikan didalam isi  kritik  saran  dan pendapat  disampaikan secara santun
# orientasi   pengenalan  tokoh  judul   tafsiran   sinopsis  evaluasi   kritik dan saran  rangkuman   alur secara garis besar
# membaca teks  mengevaluasi  memperbaiki  membenarkan
# orientasi   gambaran umum tentang apa yang akan diulas  tafsiran   gambaran pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   ringkasan atau rangkuman tentang apa yang telah diulas
# tata cahaya  mengulas tentang pencahayaan  saat drama  aspek penyutradaraan  mengulas tentang alur cerita  tata setting  mengulas tentang penempatan benda2 yang diperlukan saat drama  tata rias  mengulas makeup para pemeran drama
# orientasi   pengenalan drama  berupa judul  latar  dan tokoh  tafsiran   berisi alur drama  evaluasi   berisi tentang evaluasi drama  bisa berupa kekurangan dan saran  rangkuman   berisi tentang amanat
# kop surat  alamat surat  salam pembuka  paragraf pembuka  paragraf isi  paragraf penutup  salam penutup
# bahasa yang komunikatif  baik   benar  mudah dipahami  kata baku   kata  yang baku  memiliki arti   jangan yang tidak memiliki arti  bersifat konkret   nyata
# unsur2 teks ulasan  terdapat teks yg ingin diulas  membaca teks  mencatat hal2 pokok
# evalusai   penilaian objek   simpulan   ringkasan  orientasi   pandangan terhadap objek  tafsiran   penjelasan hal hal yang terdapat diobjek
# gagasan utama  pokok utama
# saran  kritikan  pendapat
# orientasi     pandangan awal dari pementasan  tafsiran     isi dari pementasan  evaluasi     koreksi dari pementasan  ringkasan     rangkuman  ringkasan dari apa yang dipentaskan
# orientasi   gambaran umum objek yang akan diulas  tafsiran   pandangan pengulas terhadap objek yang akan diulas  evaluasi   pendapat pengulas terhadap yang diulas  rangkuman   perbaikan yang disampaikan sang pengulas
# orientasi   pendangan umum terhadap teks ulasan  tafsiran   pandangan pengulas terhadap teks ulasan  evaluasi   penilaian terhadap teks ulasan  rangkuman   ringkasan  kesimpulan teks ulasan
# teks ulasan adalah teks yang diulas kembali
# sesuatu yang harus diperhatikan  seperti   judul  tema  tokoh dan lainnya  isi  penjelasan  rangkuman   berisi amanat
# orientasi    pengenalan tempat  dimainkan oleh siapa  jumlah pemain  tafsiran    kelebihan pada teks ulasan  evaluasi    kekurangan dalam teks ulasan  rangkuman    merangkum teks ulasan
# evaluasi   mencari kesalahan lalu dibenarkan  rangkuman   mencatat isi  tokoh   pemeran
# orientasi   gambaran umum teks ulasan  tafsiran   penafsiran hal yang diulas  evaluasi   hal   hal yang harus diperbaiki  ulasan   gambaran secara rinci tentang objek
# orientasi   gambaran tentang ulasan  rangkuman   kesimpulan dari ulasan  tafsiran   bacaan tentang ulasan
# orientasi   gambaran drama  tafsiran   berisi sinopsis drama  evaluasi berisi sesuatu yang perlu dievaluasi  rangkuman   amanat
# orientasi   mencangkup judul  dll  isi   bagian penting dalam teks ulasan  ringkasan   bagian penting yang diringkas
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   simpulan dari ulasan
# orientasi   pendapat terhadap ulasan pementasan drama  eg   penokohannya tidak terlalu dipertegas dalam pementasan drama  tafsiran   pendapat pengulas terhadap pementasan drama  evaluasi   pendapat terhadap kekurangan2 dalam pementasan drama  rangkuman   kesimpulan yang dapat ditarik terhadap ulasan teks
# anotasi   penjelasan teks ulasan  orientasi   pembicara dengan teks ulasan  evaluasi   penilaian teks ulasan  ringkasan   ringkasan teks
# orientasi    judul  tokoh  peran latar  tafsiran    menceritakan kembali  evaluasi    kritik dan saran  rangkuman    amanat
# menggunakan penomeran  menggunakan bahasa yang efektif
# urut   tahapannya urut  menggunakan bahasa yang baik dan benar
# orientasi    pembukaan atau awalan  isi    isi teks ulasan  alur    jalannya cerita  kesimpulan    inti dari semuanya atau hasil akhir
# prosedur melakukan sesuatu  menjelaskan tentang bagaimana melakukan suatu kegiatan yang hasil akhirnya berupa selesainya suatu kegiatan contoh   mencuci baju  prosedur membuat sesuatu  menjelaskan tentang bagaimana cara membuat sesuatu secara urut dan lengkap  contoh   cara membuat tempat pensil
# pembuka   prolog suatu teks ulasan untuk menyambut pembaca  isi   isi ulasan  inti dari teks ulasan  penutup   epilog suatu teks ulasan  dan disambung ucapan  terimakasih
# menggunakan bahasa yang efektif tidak bertele tele  jelas   dapat dipahami oleh pembaca  mencakup semua materi  runtut   urutan harus jelas  menggunakan bahasa yang komunikatif  memberi contoh contoh yang factual  menyampaikan informasi terbaru
# kata kata yang tepat  kata perkata harus tepat  baasa yang baik  penggunaan bahasanya
# menggunakan bahasa yang efektif  menggunakan penomeran
# orientasi   mencangkup judul  tokoh  latar  dan lain lain  tafsiran terdapat sinopsis  cerita ulang   evaluasi   meliputi kritik dan saran  rangkuman   adanya amanat
# orientasi   ulasan yang mengarah ke kesan dan detail pementasan   tafsiran   ulasan yang mengarah ke ceritanya  evaluasi   ulasan yang mengarah ke aktor  pemainnya  R   ulasan yang mengarah ke amanat  kesan penonton
# naskah   menuntun pemeran untuk berdialog  berekspresi dan bergerak  sutradara   mengatur jalannya pementasan  aktor dan aktris   pemeran dari sebuah drama  punggung   tempat bermain sebuah drama
# menyiapkan barang yang akan digunakan  buatlah sesuatu yang ingin kita mau
# orientasi    judul  tokoh   peran  latar  tafsiran   sinopsis  evaluasi   kritik dan saran  rangkuman   amanat
# judul   pengantar cerita  anotasi   dialog tokoh  ket  pengadeganan   watak tokoh  babak dan adegan   konflik pembentuk cerita
# orientasi   berisi latar belakang teks yang diulas antara lain tokoh  tema  judul  dan lainnya  tafsiran   berisi rangkaian cerita atau sinopsis dan alur  evaluasi   berisi kritik dan saran beserta argumen dan solusi permasalahan  rangkuman   berisi amanat dan kesimpulan dari teks yang diulas
# bersifat fakta  terdiri dari jawaban 5w 1h  benar benar terjadi
# naskah    dialog  sutradara    mengatur para pemain  aktor dan aktris    tokoh drama  panggung    tempat bermain drama
# kritik   pendapat yang diberikan untuk menanggapi suatu hal  saran   pendapat yang diberikan untuk menanggapi suatu hal beserta solusi untuk membenarkannya
# judul  identitas dari dialog tersebut  anotasi  keterangan yang sedang dilakukan oleh tokoh  dialog  percakapan antar tokoh  babak adegan  permasalahan yang menjadi pembangun cerita
# tokoh   peran utama dan tambahan  tema   pokok pokok cerita  latar   tempat dan waktu  amanat   pesan moral  alur   jalan cerita  bahasa  bahasa yang mudah dimengerti
# 5w   1h   who   siapa  what   apa  where   dimana   when   kapan  why   mengapa  how   bagaimana
# bahasa yang komunikatif    harus menggunakan bahasa yang baik dan benar  isinya harus lengkap    agar tidak salah membaca  terdapat salam pembuka    agar lebih sopan
# terdapat penomeran    penomeran yang urut  terdapat perintah    perintah melakukan  membuat sesuatu
# orientasi   judul  tokoh  peran latar  tafsiran   sinopsis  menceritakan ulang   evaluasi   kritik dan saran   penyutradaraan  tata rias  tata panggung  tata pencahayaan  tata musik  aktor dan aktris  rangkuman   amanat
# tema   ide yang ada didalam teks  judul   nama teks  isi   isi teks  inti dari teks  latar waktu   tempat   waktu dan tempat yang ada didalam teks
# teks usulan   teks untuk mengevaluasi sesuatu  unsur   unsur   mengevaluasi scr jujur dan objektif  mengevaluasi dengan baik dan benar  menyampaikan evaluasi dengan bahasa yang baik  menulis evaluasi di buku  menyimpan menggunakan bahasa yang komunikatif
# kritik   hanya memberitahu bahwa ada yang kurang dari kegiatan tersebut  kritik dan saran   memberitahu bahwa ada yang kurang dari kegiatan tersebut dan memberikan cara agar kekurangan tersebut berkurang
# evalusai    kritik dan saran  kritik   berkomentar tanpa membangun  saran   berkomentar dengan jalan keluar  pendapat    hal yang diungkapkan menurut sudut pandang masing masing  tafsiran    menceritakan ulang secara garis besarnya saja
# pembuka   seperti mengucap syukur  isi teks   pokok teks  penutup   salam penutup dan ucapan terima kasih
# pahami yang dibaca  memcatat hal yang penting  menanggapi apa yang kurang tepat  dll
# unsur unsur dalam teks ulasan   orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   rangkuman  simpulan isi ulasan
# orientasi   pengenalan  evaluasi   meneliti  mengevaluasi teks ulasan
# orientasi    berisi pengenalan awal terhadap apa yang kita ulas  tafsiran    berisi tentang pandangan pengulas terhadap sesuatu yang diulas  evaluasi    berisi tentang pendapat pengulas terhadap kekurangan yang terdapat pada sesuatu yang kita ulas  rangkuman    berisi tentang kesan dan pesan pengulas  dan simpulan dari semua ulasan tersebut
# teks ulasan adalah teks yang diulas dari informasi
# sebuah teks yang mengulas sebuah masalah
# orientasi   pembuka suatu teks  event   kejadian atau peristiwa  reorientasi   kesan   pesan
# terdapat kop surat  terdapat waktu  terdapat pembuka  terdapat isi  terdapat penanda tangan  terdapat penutup surat
# dengan kalimat aktif dan pasif  dengan bahasa yang baku  bahasa indonesia yang baik dan mudah dimengerti  dengan bahasa yang tidak bertele tele
# orientasi  isi  kata penutup  evaluasi
# orientasi   gambaran umum tentang objek yang dilihat  tafsiran   ulasan terhadap objek yang diulas  evaluasi   berupa pendapat pengamat terhadap objek yang dilihat  rangkuman   kesimpulan mengenai suatu objek yang dilihat
# pendapat  gagasan  komentar
# orientasi   gambaran umum tentang objek tersebut  tafsiran   pandangan  ringkasan cerita  evaluasi   kekurangan dan kesalahan dalam cerita  ringkasan   ringkasan dari teks ulasan
# unsur   unsur dalam teks ulasan   orientasi  evaluasi
# orientasi   berisi gagasan utama drama  judul  alur  latar  dll    gambaran umum  pengembangan orientasi   sinopsis drama  penjelasan   berisi objek yang diulas  ringkasan   rangkuman ulasan drama
# ulasan teks adalah   ringkasan dalam sebuah teks  judul  tokoh  latar  dll
# tema  isi  pembahasan tema  kesimpulan  hasil ulasan
# penulisan bahasa indonesia yang baik dan benar  kata kata yang tepat  penjedaan pada setiap kalimat
# bahasa yang baku  berisi pokok pokok yang penting  bahasa yang komunikatif  penulisan yang benar
# tokoh  alur  latar  penokohan  pengevaluasi  membuat sinopsis  amanat
# orientasi   gambaran pengulas terhadap objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   ringkasan atau saran terhadap objek yang diulas
# tema  judul  amanat  isi  penutup
# orientasi   berisi judul  penokohan    alur  tafsiran   sinopsis  evaluasi   kritik   saran  kesimpulan   rangkuman
# reorientasi   berunsur sedang  verbal   berunsur keras  aktual   berunsur rata
# orientasi    membahas terhadap drama yang diulas  seperti   tokoh  alur  dll  tafsiran    suatu pengulasan terhadap drama yang diulas  evaluasi    penilaian terhadap drama yang diulas  rangkuman    ringkasan
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman  ringkasan  isi ulasan
# saran  memerikan saran  kritik   mengomentari
#
# --------Fold 1--------
#
# teks ulasan adalah teks yang diulas kembali
# sesuatu yang harus diperhatikan, seperti : judul, tema, tokoh dan lainnya; isi; penjelasan; rangkuman : berisi amanat
# orientasi -> pengenalan tempat, dimainkan oleh siapa, jumlah pemain; tafsiran -> kelebihan pada teks ulasan; evaluasi -> kekurangan dalam teks ulasan; rangkuman -> merangkum teks ulasan
# evaluasi : mencari kesalahan lalu dibenarkan; rangkuman : mencatat isi; tokoh : pemeran
# orientasi : gambaran umum teks ulasan; tafsiran : penafsiran hal yang diulas; evaluasi : hal - hal yang harus diperbaiki; ulasan : gambaran secara rinci tentang objek
# orientasi : gambaran tentang ulasan; rangkuman : kesimpulan dari ulasan; tafsiran : bacaan tentang ulasan
# orientasi : gambaran drama; tafsiran : berisi sinopsis drama; evaluasi berisi sesuatu yang perlu dievaluasi; rangkuman : amanat
# orientasi : mencangkup judul, dll; isi : bagian penting dalam teks ulasan; ringkasan : bagian penting yang diringkas
# orientasi : gambaran umum tentang objek yang diulas; tafsiran : pandangan pengulas terhadap objek yang diulas; evaluasi : penilaian terhadap objek yang diulas; rangkuman : simpulan dari ulasan
# orientasi : pendapat terhadap ulasan pementasan drama, eg : penokohannya tidak terlalu dipertegas dalam pementasan drama; tafsiran : pendapat pengulas terhadap pementasan drama; evaluasi : pendapat terhadap kekurangan2 dalam pementasan drama; rangkuman : kesimpulan yang dapat ditarik terhadap ulasan teks
# anotasi : penjelasan teks ulasan; orientasi : pembicara dengan teks ulasan; evaluasi : penilaian teks ulasan; ringkasan : ringkasan teks
# orientasi -> judul, tokoh, peran latar; tafsiran -> menceritakan kembali; evaluasi -> kritik dan saran; rangkuman -> amanat
# menggunakan penomeran; menggunakan bahasa yang efektif
# urut : tahapannya urut; menggunakan bahasa yang baik dan benar
# orientasi -> pembukaan atau awalan; isi -> isi teks ulasan; alur -> jalannya cerita; kesimpulan -> inti dari semuanya atau hasil akhir
# prosedur melakukan sesuatu, menjelaskan tentang bagaimana melakukan suatu kegiatan yang hasil akhirnya berupa selesainya suatu kegiatan contoh : mencuci baju; prosedur membuat sesuatu, menjelaskan tentang bagaimana cara membuat sesuatu secara urut dan lengkap, contoh : cara membuat tempat pensil
# pembuka : prolog suatu teks ulasan untuk menyambut pembaca; isi : isi ulasan/ inti dari teks ulasan; penutup : epilog suatu teks ulasan, dan disambung ucapan 'terimakasih'
# menggunakan bahasa yang efektif tidak bertele-tele; jelas : dapat dipahami oleh pembaca; mencakup semua materi; runtut : urutan harus jelas; menggunakan bahasa yang komunikatif; memberi contoh-contoh yang factual; menyampaikan informasi terbaru
# kata-kata yang tepat; kata perkata harus tepat; baasa yang baik; penggunaan bahasanya
# menggunakan bahasa yang efektif; menggunakan penomeran
# orientasi : mencangkup judul, tokoh, latar, dan lain-lain; tafsiran terdapat sinopsis (cerita ulang); evaluasi : meliputi kritik dan saran; rangkuman : adanya amanat
# orientasi : ulasan yang mengarah ke kesan dan detail pementasan ; tafsiran : ulasan yang mengarah ke ceritanya; evaluasi : ulasan yang mengarah ke aktor/ pemainnya; R : ulasan yang mengarah ke amanat/ kesan penonton
# naskah : menuntun pemeran untuk berdialog, berekspresi dan bergerak; sutradara : mengatur jalannya pementasan; aktor dan aktris : pemeran dari sebuah drama; punggung : tempat bermain sebuah drama
# menyiapkan barang yang akan digunakan; buatlah sesuatu yang ingin kita mau
# orientasi  : judul, tokoh + peran, latar; tafsiran : sinopsis; evaluasi : kritik dan saran; rangkuman : amanat
# judul : pengantar cerita; anotasi : dialog tokoh; ket. pengadeganan : watak tokoh; babak dan adegan : konflik pembentuk cerita
# orientasi : berisi latar belakang teks yang diulas antara lain tokoh, tema, judul, dan lainnya; tafsiran : berisi rangkaian cerita atau sinopsis dan alur; evaluasi : berisi kritik dan saran beserta argumen dan solusi permasalahan; rangkuman : berisi amanat dan kesimpulan dari teks yang diulas
# bersifat fakta; terdiri dari jawaban 5w+1h; benar-benar terjadi
# naskah -> dialog; sutradara -> mengatur para pemain; aktor dan aktris -> tokoh drama; panggung -> tempat bermain drama
# kritik : pendapat yang diberikan untuk menanggapi suatu hal; saran : pendapat yang diberikan untuk menanggapi suatu hal beserta solusi untuk membenarkannya
# judul: identitas dari dialog tersebut; anotasi: keterangan yang sedang dilakukan oleh tokoh; dialog: percakapan antar tokoh; babak adegan: permasalahan yang menjadi pembangun cerita
# tokoh : peran utama dan tambahan; tema : pokok-pokok cerita; latar : tempat dan waktu; amanat : pesan moral; alur : jalan cerita; bahasa: bahasa yang mudah dimengerti
# 5w + 1h ; who = siapa; what = apa; where = dimana ; when = kapan; why = mengapa; how = bagaimana
# bahasa yang komunikatif -> harus menggunakan bahasa yang baik dan benar; isinya harus lengkap -> agar tidak salah membaca; terdapat salam pembuka -> agar lebih sopan
# terdapat penomeran -> penomeran yang urut; terdapat perintah -> perintah melakukan/ membuat sesuatu
# orientasi : judul, tokoh, peran latar; tafsiran : sinopsis (menceritakan ulang); evaluasi : kritik dan saran , penyutradaraan, tata rias, tata panggung, tata pencahayaan, tata musik, aktor dan aktris; rangkuman : amanat
# tema : ide yang ada didalam teks; judul : nama teks; isi : isi teks/ inti dari teks; latar waktu & tempat : waktu dan tempat yang ada didalam teks
# teks usulan : teks untuk mengevaluasi sesuatu; unsur - unsur : mengevaluasi scr jujur dan objektif; mengevaluasi dengan baik dan benar; menyampaikan evaluasi dengan bahasa yang baik; menulis evaluasi di buku; menyimpan menggunakan bahasa yang komunikatif
# kritik : hanya memberitahu bahwa ada yang kurang dari kegiatan tersebut; kritik dan saran : memberitahu bahwa ada yang kurang dari kegiatan tersebut dan memberikan cara agar kekurangan tersebut berkurang
# evalusai -> kritik dan saran, kritik : berkomentar tanpa membangun, saran : berkomentar dengan jalan keluar; pendapat -> hal yang diungkapkan menurut sudut pandang masing-masing; tafsiran -> menceritakan ulang secara garis besarnya saja
# pembuka : seperti mengucap syukur; isi teks : pokok teks; penutup : salam penutup dan ucapan terima kasih
# pahami yang dibaca, memcatat hal yang penting, menanggapi apa yang kurang tepat, dll
# unsur-unsur dalam teks ulasan:; orientasi : gambaran umum tentang objek yang diulas; tafsiran : pandangan pengulas terhadap objek yang diulas; evaluasi : penilaian terhadap objek yang diulas; rangkuman : rangkuman/ simpulan isi ulasan
# orientasi : pengenalan; evaluasi : meneliti/ mengevaluasi teks ulasan
# orientasi -> berisi pengenalan awal terhadap apa yang kita ulas; tafsiran -> berisi tentang pandangan pengulas terhadap sesuatu yang diulas; evaluasi -> berisi tentang pendapat pengulas terhadap kekurangan yang terdapat pada sesuatu yang kita ulas; rangkuman -> berisi tentang kesan dan pesan pengulas, dan simpulan dari semua ulasan tersebut
# teks ulasan adalah teks yang diulas dari informasi
# sebuah teks yang mengulas sebuah masalah
# orientasi : pembuka suatu teks; event : kejadian atau peristiwa; reorientasi : kesan & pesan
# terdapat kop surat; terdapat waktu; terdapat pembuka; terdapat isi; terdapat penanda tangan; terdapat penutup surat
# dengan kalimat aktif dan pasif; dengan bahasa yang baku; bahasa indonesia yang baik dan mudah dimengerti; dengan bahasa yang tidak bertele-tele
# orientasi, isi, kata penutup, evaluasi
# orientasi : gambaran umum tentang objek yang dilihat; tafsiran : ulasan terhadap objek yang diulas; evaluasi : berupa pendapat pengamat terhadap objek yang dilihat; rangkuman : kesimpulan mengenai suatu objek yang dilihat
# pendapat, gagasan, komentar
# orientasi : gambaran umum tentang objek tersebut; tafsiran : pandangan/ ringkasan cerita; evaluasi : kekurangan dan kesalahan dalam cerita; ringkasan : ringkasan dari teks ulasan
# unsur - unsur dalam teks ulasan ; orientasi; evaluasi
# orientasi : berisi gagasan utama drama (judul, alur, latar, dll)./ gambaran umum; pengembangan orientasi : sinopsis drama; penjelasan : berisi objek yang diulas; ringkasan : rangkuman ulasan drama
# ulasan teks adalah : ringkasan dalam sebuah teks; judul; tokoh; latar; dll
# tema; isi; pembahasan tema; kesimpulan; hasil ulasan
# penulisan bahasa indonesia yang baik dan benar; kata-kata yang tepat; penjedaan pada setiap kalimat
# bahasa yang baku, berisi pokok-pokok yang penting, bahasa yang komunikatif, penulisan yang benar
# tokoh, alur, latar, penokohan, pengevaluasi, membuat sinopsis, amanat
# orientasi : gambaran pengulas terhadap objek yang diulas; tafsiran : pandangan pengulas terhadap objek yang diulas; evaluasi : penilaian terhadap objek yang diulas; rangkuman : ringkasan atau saran terhadap objek yang diulas
# tema, judul, amanat, isi, penutup
# orientasi : berisi judul, penokohan, & alur; tafsiran : sinopsis; evaluasi : kritik & saran; kesimpulan : rangkuman
# reorientasi : berunsur sedang; verbal : berunsur keras; aktual : berunsur rata
# orientasi -> membahas terhadap drama yang diulas, seperti : tokoh, alur, dll; tafsiran -> suatu pengulasan terhadap drama yang diulas; evaluasi -> penilaian terhadap drama yang diulas; rangkuman -> ringkasan
# orientasi : gambaran umum tentang objek yang diulas; tafsiran : pandangan pengulas terhadap objek yang diulas; evaluasi : penilaian terhadap objek yang diulas; rangkuman: ringkasan/ isi ulasan
# saran: memerikan saran; kritik : mengomentari
# teks ulasan adalah teks yang diulas kembali
# sesuatu yang harus diperhatikan  seperti   judul  tema  tokoh dan lainnya  isi  penjelasan  rangkuman   berisi amanat
# orientasi    pengenalan tempat  dimainkan oleh siapa  jumlah pemain  tafsiran    kelebihan pada teks ulasan  evaluasi    kekurangan dalam teks ulasan  rangkuman    merangkum teks ulasan
# evaluasi   mencari kesalahan lalu dibenarkan  rangkuman   mencatat isi  tokoh   pemeran
# orientasi   gambaran umum teks ulasan  tafsiran   penafsiran hal yang diulas  evaluasi   hal   hal yang harus diperbaiki  ulasan   gambaran secara rinci tentang objek
# orientasi   gambaran tentang ulasan  rangkuman   kesimpulan dari ulasan  tafsiran   bacaan tentang ulasan
# orientasi   gambaran drama  tafsiran   berisi sinopsis drama  evaluasi berisi sesuatu yang perlu dievaluasi  rangkuman   amanat
# orientasi   mencangkup judul  dll  isi   bagian penting dalam teks ulasan  ringkasan   bagian penting yang diringkas
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   simpulan dari ulasan
# orientasi   pendapat terhadap ulasan pementasan drama  eg   penokohannya tidak terlalu dipertegas dalam pementasan drama  tafsiran   pendapat pengulas terhadap pementasan drama  evaluasi   pendapat terhadap kekurangan2 dalam pementasan drama  rangkuman   kesimpulan yang dapat ditarik terhadap ulasan teks
# anotasi   penjelasan teks ulasan  orientasi   pembicara dengan teks ulasan  evaluasi   penilaian teks ulasan  ringkasan   ringkasan teks
# orientasi    judul  tokoh  peran latar  tafsiran    menceritakan kembali  evaluasi    kritik dan saran  rangkuman    amanat
# menggunakan penomeran  menggunakan bahasa yang efektif
# urut   tahapannya urut  menggunakan bahasa yang baik dan benar
# orientasi    pembukaan atau awalan  isi    isi teks ulasan  alur    jalannya cerita  kesimpulan    inti dari semuanya atau hasil akhir
# prosedur melakukan sesuatu  menjelaskan tentang bagaimana melakukan suatu kegiatan yang hasil akhirnya berupa selesainya suatu kegiatan contoh   mencuci baju  prosedur membuat sesuatu  menjelaskan tentang bagaimana cara membuat sesuatu secara urut dan lengkap  contoh   cara membuat tempat pensil
# pembuka   prolog suatu teks ulasan untuk menyambut pembaca  isi   isi ulasan  inti dari teks ulasan  penutup   epilog suatu teks ulasan  dan disambung ucapan  terimakasih
# menggunakan bahasa yang efektif tidak bertele tele  jelas   dapat dipahami oleh pembaca  mencakup semua materi  runtut   urutan harus jelas  menggunakan bahasa yang komunikatif  memberi contoh contoh yang factual  menyampaikan informasi terbaru
# kata kata yang tepat  kata perkata harus tepat  baasa yang baik  penggunaan bahasanya
# menggunakan bahasa yang efektif  menggunakan penomeran
# orientasi   mencangkup judul  tokoh  latar  dan lain lain  tafsiran terdapat sinopsis  cerita ulang   evaluasi   meliputi kritik dan saran  rangkuman   adanya amanat
# orientasi   ulasan yang mengarah ke kesan dan detail pementasan   tafsiran   ulasan yang mengarah ke ceritanya  evaluasi   ulasan yang mengarah ke aktor  pemainnya  R   ulasan yang mengarah ke amanat  kesan penonton
# naskah   menuntun pemeran untuk berdialog  berekspresi dan bergerak  sutradara   mengatur jalannya pementasan  aktor dan aktris   pemeran dari sebuah drama  punggung   tempat bermain sebuah drama
# menyiapkan barang yang akan digunakan  buatlah sesuatu yang ingin kita mau
# orientasi    judul  tokoh   peran  latar  tafsiran   sinopsis  evaluasi   kritik dan saran  rangkuman   amanat
# judul   pengantar cerita  anotasi   dialog tokoh  ket  pengadeganan   watak tokoh  babak dan adegan   konflik pembentuk cerita
# orientasi   berisi latar belakang teks yang diulas antara lain tokoh  tema  judul  dan lainnya  tafsiran   berisi rangkaian cerita atau sinopsis dan alur  evaluasi   berisi kritik dan saran beserta argumen dan solusi permasalahan  rangkuman   berisi amanat dan kesimpulan dari teks yang diulas
# bersifat fakta  terdiri dari jawaban 5w 1h  benar benar terjadi
# naskah    dialog  sutradara    mengatur para pemain  aktor dan aktris    tokoh drama  panggung    tempat bermain drama
# kritik   pendapat yang diberikan untuk menanggapi suatu hal  saran   pendapat yang diberikan untuk menanggapi suatu hal beserta solusi untuk membenarkannya
# judul  identitas dari dialog tersebut  anotasi  keterangan yang sedang dilakukan oleh tokoh  dialog  percakapan antar tokoh  babak adegan  permasalahan yang menjadi pembangun cerita
# tokoh   peran utama dan tambahan  tema   pokok pokok cerita  latar   tempat dan waktu  amanat   pesan moral  alur   jalan cerita  bahasa  bahasa yang mudah dimengerti
# 5w   1h   who   siapa  what   apa  where   dimana   when   kapan  why   mengapa  how   bagaimana
# bahasa yang komunikatif    harus menggunakan bahasa yang baik dan benar  isinya harus lengkap    agar tidak salah membaca  terdapat salam pembuka    agar lebih sopan
# terdapat penomeran    penomeran yang urut  terdapat perintah    perintah melakukan  membuat sesuatu
# orientasi   judul  tokoh  peran latar  tafsiran   sinopsis  menceritakan ulang   evaluasi   kritik dan saran   penyutradaraan  tata rias  tata panggung  tata pencahayaan  tata musik  aktor dan aktris  rangkuman   amanat
# tema   ide yang ada didalam teks  judul   nama teks  isi   isi teks  inti dari teks  latar waktu   tempat   waktu dan tempat yang ada didalam teks
# teks usulan   teks untuk mengevaluasi sesuatu  unsur   unsur   mengevaluasi scr jujur dan objektif  mengevaluasi dengan baik dan benar  menyampaikan evaluasi dengan bahasa yang baik  menulis evaluasi di buku  menyimpan menggunakan bahasa yang komunikatif
# kritik   hanya memberitahu bahwa ada yang kurang dari kegiatan tersebut  kritik dan saran   memberitahu bahwa ada yang kurang dari kegiatan tersebut dan memberikan cara agar kekurangan tersebut berkurang
# evalusai    kritik dan saran  kritik   berkomentar tanpa membangun  saran   berkomentar dengan jalan keluar  pendapat    hal yang diungkapkan menurut sudut pandang masing masing  tafsiran    menceritakan ulang secara garis besarnya saja
# pembuka   seperti mengucap syukur  isi teks   pokok teks  penutup   salam penutup dan ucapan terima kasih
# pahami yang dibaca  memcatat hal yang penting  menanggapi apa yang kurang tepat  dll
# unsur unsur dalam teks ulasan   orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   rangkuman  simpulan isi ulasan
# orientasi   pengenalan  evaluasi   meneliti  mengevaluasi teks ulasan
# orientasi    berisi pengenalan awal terhadap apa yang kita ulas  tafsiran    berisi tentang pandangan pengulas terhadap sesuatu yang diulas  evaluasi    berisi tentang pendapat pengulas terhadap kekurangan yang terdapat pada sesuatu yang kita ulas  rangkuman    berisi tentang kesan dan pesan pengulas  dan simpulan dari semua ulasan tersebut
# teks ulasan adalah teks yang diulas dari informasi
# sebuah teks yang mengulas sebuah masalah
# orientasi   pembuka suatu teks  event   kejadian atau peristiwa  reorientasi   kesan   pesan
# terdapat kop surat  terdapat waktu  terdapat pembuka  terdapat isi  terdapat penanda tangan  terdapat penutup surat
# dengan kalimat aktif dan pasif  dengan bahasa yang baku  bahasa indonesia yang baik dan mudah dimengerti  dengan bahasa yang tidak bertele tele
# orientasi  isi  kata penutup  evaluasi
# orientasi   gambaran umum tentang objek yang dilihat  tafsiran   ulasan terhadap objek yang diulas  evaluasi   berupa pendapat pengamat terhadap objek yang dilihat  rangkuman   kesimpulan mengenai suatu objek yang dilihat
# pendapat  gagasan  komentar
# orientasi   gambaran umum tentang objek tersebut  tafsiran   pandangan  ringkasan cerita  evaluasi   kekurangan dan kesalahan dalam cerita  ringkasan   ringkasan dari teks ulasan
# unsur   unsur dalam teks ulasan   orientasi  evaluasi
# orientasi   berisi gagasan utama drama  judul  alur  latar  dll    gambaran umum  pengembangan orientasi   sinopsis drama  penjelasan   berisi objek yang diulas  ringkasan   rangkuman ulasan drama
# ulasan teks adalah   ringkasan dalam sebuah teks  judul  tokoh  latar  dll
# tema  isi  pembahasan tema  kesimpulan  hasil ulasan
# penulisan bahasa indonesia yang baik dan benar  kata kata yang tepat  penjedaan pada setiap kalimat
# bahasa yang baku  berisi pokok pokok yang penting  bahasa yang komunikatif  penulisan yang benar
# tokoh  alur  latar  penokohan  pengevaluasi  membuat sinopsis  amanat
# orientasi   gambaran pengulas terhadap objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   ringkasan atau saran terhadap objek yang diulas
# tema  judul  amanat  isi  penutup
# orientasi   berisi judul  penokohan    alur  tafsiran   sinopsis  evaluasi   kritik   saran  kesimpulan   rangkuman
# reorientasi   berunsur sedang  verbal   berunsur keras  aktual   berunsur rata
# orientasi    membahas terhadap drama yang diulas  seperti   tokoh  alur  dll  tafsiran    suatu pengulasan terhadap drama yang diulas  evaluasi    penilaian terhadap drama yang diulas  rangkuman    ringkasan
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman  ringkasan  isi ulasan
# saran  memerikan saran  kritik   mengomentari
# orientasi   berisi informasi dasar drama  tokoh  latar  dll   tafsiran   sinopsis drama  evaluasi   penilaian terhadap drama  rangkuman   ringkasan drama
# orientasi   gambaran umum mengenai objek  tafsiran   gambaran atau pendapat penonton mengenai objek  evaluasi   meneliti kekurangan objek  ranguman   ringkasan   rangkuman atau ringkasan secara keseluruhan
# ringkasan  evaluasi  orientasi  rangkuman
# orientasi   pengenalan  tafsiran   pendahuluan  evaluasi   pendapat  kesimpulan   amanat  kesimpulan
# orientasi   membaca cepat benar  evaluasi   mengevaluasi bacaan  rangkuman   merangkum bacaan  memahami   memahami bacaan
# paragraf pembuka   pembukaan teks  paragraf isi   isi teks  paragraf penutup   penutup teks
# tema  topik  sumber  waktu dan tempat  kejadian
# orientasi  tafsiran  rangkuman  ulasan
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   ringkasan   kesimpulan ulasan
# evaluasi   mengevaluasi yang diulas  ringkasan   ringkasan  kesimpulan isi ulasan  orientas
# pencahayaan   dimatikan saat pergantian adegan  kostum   agar penonton dapat membedakan peran  suara   harus keras walaupun tidak memakai mikrofon  latar   harus jelas latarnya agar mudah dipahami  musik   pendukung suasana drama
# teknik outline  teknik olah suara  teknik olah wajah
# orientasi   gambaran umum tentang objek yg diulas  tafsiran   pandangan pengulas dari objek yg diulas  evaluasi  penelitian  pengamatan  evaluasi terhadap objek yang diulas  ringkasan   rangkuman dari isi ulasan
# orientasi   menggambarkan tentang objek yang kita lihat  tafsiran   menafsirkan objek yang kita lihat  evalusai   mengevaluasi objek yang dilihat  rangkuman   merangkum dari apa yang kita lihat
# tema   hal yang akan dibahas  alur   jalan cerita  latar   tempat dan waktu dilaksanakan  bahasa   kata yang sesuai  amanat   hal yang bisa diambil
# tata riasan  tata cahaya  tata musik  tata penyutradaraan
# orientasi   terdiri dari nama tokoh  peran tokoh  tema  dan judul  isi   terdiri dari sinopsis  alur  dan latar  evalusai   terdiri kritik dan saran tentang aspek aspek drama  aspek akting  aspek kostum  aspek tata rias  aspek setting  aspek pencahayaan dan lainnya  rangkuman   terdiri dari amanat yang ingin disampaikan
# kritik   mengomentari negatif  saran   memberikan solusi positif
# 5w   1h  what  apa   when  kapan   who  siapa   where  dimana   why  mengapa   how  bagaimana
# orientasi   penjelasan seperti tokoh  judul  setting  tafsiran   alur drama  evaluasi   kritik dan saran  rangkuman   kesimpulan  amanat
# orientasi   gambaran umum tentang objek yang diulas  judul  contoh   peran  latar   tafsiran   pandangan pada objek yang diulas  sinopsis   evaluasi   penilaian tentang objek yang diulas  kritik  saran   rangkuman   ringkasan tentang ulasan tersebut  amanat
# non formal   tidak harus menggunakan kata bantu  sopan   tidak menggunakan kata kasar  jelas   harus jelas  mudah dipahami
# teks ulasan membuat sesuatu   membuat relief tekan  teks ulasan melakukan sesuatu   menyetrika  memasak
# orientasi   adalah gambaran ulang terhadap objek  tafsiran   adalah ulasan terhadap objek  evaluasi   adalah penilaian terhadap objek  rangkuman   ringkasan isi ulasan
# judul   judul dalam teks tersebut  anotasi  dialog   percakapan  babak  adegan
# volume suara   dapat didengar oleh seluruh audiens  vokal   dapat didengar secara jelas  penjelasan   pemberhentian ditengah atau diakhir kalimat  ekspresi   mimik wajah  gerak gerik   mengurangi gerakan yang tidak perlu  bahasa yang komunikatif  penggunaan bahasa indonesia dengan baik dan benar
# pembukaan    salam  isi    tujuan  penutup   salam penutup dan terimakasih
# sutradara   mengatur jalannya pementasan   alur   jalan cerita  panggung   tempat pementasan drama  amanat   pesan yang terkandung dalam drama
# orientasi   gambaran umum tentang objek yang diulas  tafsiran   gambaran pengulas tentang objek yang diulas  evaluasi   isi usulan   saran saran pengulas  rangkuman   ringkasan ulasan   amanat
# ada penomorannya  secara urutan  gampang dipahami
# 5w   1h    5w     why  who  what  why  where   1h   how  berupa fakta  judul
# bahasa komunikatif   menggunakan bahasa indonesia yang baik dan benar  tanda baca   harus memperhatikan tanda baca  huruf kapital   harus memperhatikan penggunaan huruf besar
# bersifat benar  bersifat aktual  berasal dari sumber yang terpercaya
# teks usulan   tema  tokoh  latar  alur  amanat  bahasa
# bahasa    bahasa yang digunakan bagaimana  pokok pokok informasi    isi dari teks tersebut
# pendapat  gagasan utama  alur
# bahasa yang baik dan benar  menggunakan bahasa baku
# alur  ringkasan  kritik saran  evaluasi  sinopsis
# penyutradaraan   sutradara adala orang yang mengatur tim dan jalannya drama  aktor  aktris   peran  yang memerankan tokoh  tata cahaya   cahaya  gelap terang  tata rias   costum  make up  tata musik   backsound drama tersebut  dialog   pembicaraan yang dilakukan antar tokoh
# tek usulan adalah teks yang bertujuan untuk mengulas sebuah cerita
# orientasi   gambaran umum tentang sesuatu yang akan diulas  cth   tokoh  latar  tafsiran   pandangan pengulas terhadap sesuatu yang akan diulas   sinopsis   evaluasi   penilaian terhadap sesuatu yang diulas bisa berupa kritik  saran  rangkuman   ringkasan  isi dari yang diulas  amanat
# what  apa    apa yang dilakukan   who  siapa    siapa yang melakukannya    when  kapan    kapan dilakukannya   where  dimana    dimana melakukannya    why  mengapa    mengapa ini dilakukan     how  bagaimana    bagaimana cara melakukannya
# orientasi   penggamar semuanya pada teks  tokoh  tempat  latar  suasana  dll  tafsiran  pandangan pengamat tentang apa yang terjadi  evaluasi   penilaian kurang dan lebihnya  rangkuman   simpulan dari teks
# orientasi   gambaran umum mengenai objek yang diulas  tafsiran   pandangan pengulas terhadap objek yang diulas  evaluasi   penilaian mengenai objek yang diulas  rangkuman   kesimpulan atau ringkasan dari ulasan
# teks ulasan   teks yang mengulas sesuatu  unsur unsur   rangkuman   menulis hasil ringkasan  orientasi   melihat secara objektif  argumen   melihat secara faktual  reorientasi   melihat secara aktual
# jelas  mudah difahami  bahasa baku  harus ada pokok pokok intinya
# orientasi   pengenalan tokoh  aktor  aktris  argumen   menemukan kesalahan kesalahan pada teks drama  evaluasi   mengevaluasi kesalahan kesalahan pada teks drama  amanat   pesan pesan yang dapat diberikan pada naskah drama
# orientasi   menggambarkan teks yang diulas  tafsiran   seperti sinopsi  evaluasi   penilaian terhadap teks yang diulas
# orientasi   penjelasan dari drama  judul   tema dari drama  bahasa   bahasa harus baku  amanat   pesan yang disampaikan  pesan moral
# teks prosedur melakukan  yaitu melakukan sesuatu rangkaian kegiatan yang hasil akhirnya adalah akhir kegiatan  teks prosedur membuat  yaitu teks urutan membuat sesuatu yang hasil akhirnya produk
# orientasi   gambaran umum tentang objek yang ingin diulas  tafsiran   pandangan tentang objek yang ingin diulas  ringkasan dan sinopsis   evaluasi   penilaian objek yang ingin diulas  rangkuman   rangkuman atau isi dari hasil ulasan  amanat
# orientasi   gambaran luas tentang sesuatu yang diulas  tafsiran   pandangan pengulas terhadap sesuatu yang diulas  ringkasan   rangkuman atau kesimpulan dari suatu yang diulas  evaluasi   penilaian terhadap sesuatu yang diulas
# unsur unsur teks ulasan    berisi hal hal yang akan disampaikan  disampaikan secara komunikatif  kesimpulan  pokok pokok yang disampaikan didalam isi  kritik  saran  dan pendapat  disampaikan secara santun
# orientasi   pengenalan  tokoh  judul   tafsiran   sinopsis  evaluasi   kritik dan saran  rangkuman   alur secara garis besar
# membaca teks  mengevaluasi  memperbaiki  membenarkan
# orientasi   gambaran umum tentang apa yang akan diulas  tafsiran   gambaran pengulas terhadap objek yang diulas  evaluasi   penilaian terhadap objek yang diulas  rangkuman   ringkasan atau rangkuman tentang apa yang telah diulas
# tata cahaya  mengulas tentang pencahayaan  saat drama  aspek penyutradaraan  mengulas tentang alur cerita  tata setting  mengulas tentang penempatan benda2 yang diperlukan saat drama  tata rias  mengulas makeup para pemeran drama
# orientasi   pengenalan drama  berupa judul  latar  dan tokoh  tafsiran   berisi alur drama  evaluasi   berisi tentang evaluasi drama  bisa berupa kekurangan dan saran  rangkuman   berisi tentang amanat
# kop surat  alamat surat  salam pembuka  paragraf pembuka  paragraf isi  paragraf penutup  salam penutup
# bahasa yang komunikatif  baik   benar  mudah dipahami  kata baku   kata  yang baku  memiliki arti   jangan yang tidak memiliki arti  bersifat konkret   nyata
# unsur2 teks ulasan  terdapat teks yg ingin diulas  membaca teks  mencatat hal2 pokok
# evalusai   penilaian objek   simpulan   ringkasan  orientasi   pandangan terhadap objek  tafsiran   penjelasan hal hal yang terdapat diobjek
# gagasan utama  pokok utama
# saran  kritikan  pendapat
# orientasi     pandangan awal dari pementasan  tafsiran     isi dari pementasan  evaluasi     koreksi dari pementasan  ringkasan     rangkuman  ringkasan dari apa yang dipentaskan
# orientasi   gambaran umum objek yang akan diulas  tafsiran   pandangan pengulas terhadap objek yang akan diulas  evaluasi   pendapat pengulas terhadap yang diulas  rangkuman   perbaikan yang disampaikan sang pengulas
# orientasi   pendangan umum terhadap teks ulasan  tafsiran   pandangan pengulas terhadap teks ulasan  evaluasi   penilaian terhadap teks ulasan  rangkuman   ringkasan  kesimpulan teks ulasan

# %%
import h5py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-c9f0b8c65221> in <module>()
# ----> 1 import h5py
#
# ~/.anaconda3/lib/python3.6/site-packages/h5py/__init__.py in <module>()
#      24 # We tried working around this by using "package_dir" but that breaks Cython.
#      25 try:
# ---> 26     from . import _errors
#      27 except ImportError:
#      28     import os.path as _op
#
# ImportError: cannot import name '_errors'
